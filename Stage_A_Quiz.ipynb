# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sts
url='https://github.com/WalePhenomenon/climate_change/blob/master/fuel_ferc1.csv?raw=true'
fuel_data = pd.read_csv(url, error_bad_lines=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
A = [1,2,3,4,5,6]
B = [13,21,34]
A_B = A+B
print (A_B)
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %%
# To create an identity matrix
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
# To find the 75th percentile and standard deviation
fuel_data.describe(include='all')
# Out:
#                       record_id  ...  fuel_cost_per_mmbtu
# count                     29523  ...         29523.000000
# unique                    29523  ...                  NaN
# top     f1_fuel_2003_12_147_1_1  ...                  NaN
# freq                          1  ...                  NaN
# mean                        NaN  ...            19.304354
# std                         NaN  ...          2091.540939
# min                         NaN  ...           -41.501000
# 25%                         NaN  ...             1.940000
# 50%                         NaN  ...             4.127000
# 75%                         NaN  ...             7.745000
# max                         NaN  ...        359278.000000
#
# [11 rows x 11 columns]

# %%
# To find Skewness and Kurtosis
from scipy.stats import skew, kurtosis
print(skew(fuel_data.fuel_qty_burned))
print(kurtosis(fuel_data.fuel_qty_burned))
# Out:
# 15.850690077422112
# 651.2589365474387

# %%
# To check for missing values
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
# To find the percentage of missing rows
fuel_data.dropna()
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 0        f1_fuel_1994_12_1_0_7  ...                1.121
# 1       f1_fuel_1994_12_1_0_10  ...                1.120
# 2        f1_fuel_1994_12_2_0_1  ...                1.650
# 3        f1_fuel_1994_12_2_0_7  ...                1.970
# 4       f1_fuel_1994_12_2_0_10  ...                2.570
# ...                        ...  ...                  ...
# 29518  f1_fuel_2018_12_12_0_13  ...                9.030
# 29519   f1_fuel_2018_12_12_1_1  ...                6.950
# 29520  f1_fuel_2018_12_12_1_10  ...                8.990
# 29521  f1_fuel_2018_12_12_1_13  ...                1.110
# 29522  f1_fuel_2018_12_12_1_14  ...               11.680
#
# [29343 rows x 11 columns]

# %%
(29523-29343)/29523*100
# Out:
# 0.609694136774718

# %%
# To find the most burned Fuel type by plotting a bar graph
plt.bar(fuel_data.fuel_type_code_pudl, fuel_data.fuel_cost_per_unit_burned)
plt.xlabel("Fuel Type")
plt.ylabel("Fuel Cost per Unit Burned")
# Out:
# Text(0, 0.5, 'Fuel Cost per Unit Burned')
